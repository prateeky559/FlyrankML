# %% [markdown]
# <a href="https://colab.research.google.com/github/prateeky559/FlyrankML/blob/main/work/notebooks/w04_baseline_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/prateeky559/FlyrankML/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %% [markdown]
# ## My Rule
#
# The baseline rule prioritizes pages that are:
# - Older content
# - Low CTR
# - High impressions
#
# Older pages with low CTR and higher impressions receive higher scores because refreshing them may improve performance.
#
# ### Reason Codes
#
# - STALE_LOW_CTR
# - STALE_HIGH_VOLUME
# - LOW_CTR
# - HIGH_PRIORITY Baseline Rule
#
# This baseline rule identifies pages that should be refreshed.
#
# The score is based on three signals:
#
# 1. Older content receives higher priority.
# 2. Pages with low CTR receive higher priority.
# 3. Pages with higher search volume receive higher priority because improvements may have larger impact.
#
# Pages with higher scores are ranked first.
#
# ### Reason Codes
#
# | Code | Meaning |
# |------|---------|
# | STALE_LOW_CTR | Old page with low CTR |
# | STALE_HIGH_VOLUME | Old page with high impressions |
# | LOW_CTR | CTR is below expected |
# | HIGH_PRIORITY | Highest overall score |

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
# !git clone https://github.com/prateeky559/FlyrankML.git
# Out:
# Cloning into 'FlyrankML'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 339 (delta 196), reused 283 (delta 163), pack-reused 0 (from 0)
# Receiving objects: 100% (339/339), 1.88 MiB | 13.00 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
# !ls /content
# Out:
# FlyrankML  sample_data

# %%
# !find /content/FlyrankML -name "content_refresh_anonymized.csv"
# Out:
# /content/FlyrankML/data/raw/content_refresh_anonymized.csv

# %%
import pandas as pd

df = pd.read_csv("/content/FlyrankML/data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# !git clone https://github.com/prateeky559/FlyrankML.git
# Out:
# fatal: destination path 'FlyrankML' already exists and is not an empty directory.

# %%
import pandas as pd

df = pd.read_csv("/content/FlyrankML/data/raw/content_refresh_anonymized.csv")

print(df.head())
print(df.columns.tolist())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# !find /content/FlyrankML/ -type d
# Out:
# /content/FlyrankML/
# /content/FlyrankML/outputs
# /content/FlyrankML/outputs/charts
# /content/FlyrankML/.github
# /content/FlyrankML/.github/workflows
# /content/FlyrankML/skills
# /content/FlyrankML/skills/writing-data-contracts
# /content/FlyrankML/skills/flyrank
# /content/FlyrankML/skills/flyrank/flyrank-context
# /content/FlyrankML/skills/flyrank/flyrank-data
# /content/FlyrankML/skills/directing-your-ai-assistant
# /content/FlyrankML/skills/building-baselines
# /content/FlyrankML/skills/deploying-static-pages
# /content/FlyrankML/skills/hunting-leakage-and-validating
# /content/FlyrankML/skills/writing-honest-claims
# /content/FlyrankML/skills/querying-big-datasets
# /content/FlyrankML/skills/framing-ml-problems
# /content/FlyrankML/skills/auditing-signals
# /content/FlyrankML/skills/writing-research-papers
# /content/FlyrankML/skills/training-honest-models
# /content/FlyrankML/data
# /content/FlyrankML/data/raw
# /content/FlyrankML/work
# /content/FlyrankML/work/notebooks
# ...

# %%
queue.to_csv(
    "/content/FlyrankML/outputs/baseline_action_score.csv",
    index=False
)

print("CSV Saved Successfully!")

# %%
import os

os.makedirs("/content/FlyrankML/work/outputs", exist_ok=True)

# %%
queue.to_csv(
    "/content/FlyrankML/outputs/baseline_action_score.csv",
    index=False
)

print("CSV Saved Successfully!")

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
top20 = queue.head(20)

for rank, (_, row) in enumerate(top20.iterrows(), start=1):
    print(f"""
Rank: {rank}
Content ID: {row['content_id']}
Action: {row['action']}
Reason Code: {row['reason_code']}
Confidence: Medium

Why selected:
High baseline score due to older content and/or low CTR.

What would make it wrong?
The page may be seasonal, recently updated outside the available data, or business priorities may differ.
""")

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %% [markdown]
# ## Weak Picks
#
# Some lower-ranked pages may not require immediate refresh because:
#
# - Traffic may be seasonal.
# - The content may have been updated recently but not reflected in the dataset.
# - Business context is not available in the data.
#
# ## Leakage Check
#
# - No future information was used.
# - No product-generated flags were used.
# - Only historical metrics (CTR, impressions, content age) were used.
# - This baseline is intended only as decision support.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
