# %% [markdown]
# <a href="https://colab.research.google.com/github/prateeky559/FlyrankML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/prateeky559/FlyrankML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ### ML Task Type
#
# I selected the **Content Refresh** lane. I frame this as a **classification** problem because the goal is to identify whether a webpage is likely to need a content refresh based on its historical performance and content-related features. The model will help classify pages into categories such as likely to need refresh or not, allowing content teams to prioritize their work more effectively.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ### Target / Proxy
#
# For this project, I will use **trend_direction** as a proxy target. Pages marked as **"down"** indicate declining performance and are strong candidates for a content refresh. The model will learn patterns from the available features to help identify pages that may require attention. This target is suitable for the starter dataset because it reflects the current performance trend of each page.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ### Success Metric
#
# The success of this project will be measured using **Precision** and **Recall**. Precision is important because it helps ensure that pages recommended for refresh actually need attention, reducing unnecessary work. Recall is also important because missing pages that are truly declining could lead to lost traffic and missed opportunities. Together, these metrics provide a balanced way to evaluate how well the model supports content refresh decisions.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ### Unit of Analysis
#
# The unit of analysis in this project is **one website page**. Each row in the dataset represents a single content page with features such as search volume, impressions, clicks, sessions, content age, and trend information. The model will analyze each page independently to determine whether it should be prioritized for a content refresh.

# %%
# !git clone https://github.com/prateeky559/FlyrankML.git
# Out:
# Cloning into 'FlyrankML'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 339 (delta 196), reused 283 (delta 163), pack-reused 0 (from 0)
# Receiving objects: 100% (339/339), 1.88 MiB | 14.91 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
# %cd FlyrankML
# Out:
# /content/FlyrankML/FlyrankML

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show a few important columns
unit_df = df[
    [
        "content_id",
        "client_id",
        "search_volume",
        "impressions_90d",
        "clicks_90d",
        "content_age_days",
        "trend_direction",
    ]
]

print("One row = One Website Page")
display(unit_df.head())
# Out:
# One row = One Website Page
#              content_id          client_id  search_volume  impressions_90d  \
# 0  content_304f48230142  client_f369cb89fc           10.0             3803
# 1  content_a1fb4e703a9e  client_4e07408562           90.0            15320
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0            12581
# 3  content_331d6c4de07b  client_19581e27de           10.0            11751
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0            19140
#
#    clicks_90d  content_age_days trend_direction
# 0          29               187            down
# 1           7               445            down
# 2          11               141            down
# 3          58               463          stable
# 4          24               263            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule, such as refreshing every page older than 180 days or every page with low clicks, cannot capture the combined effect of multiple factors. A page's performance depends on search volume, impressions, clicks, engagement, content age, competition, and other features working together.
# Machine learning can learn patterns from many features at the same time and identify pages that are more likely to need a content refresh. This provides better decision support than relying on a single rule and helps content teams prioritize their work more effectively.

# %% [markdown]
# Before you submit, confirm each line honestly:
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
